# %%
from dotenv import load_dotenv
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain.tools import tool
from langchain.agents import create_agent
import base64
load_dotenv()
# Out:
# True

# %%
with open("blood_work.png", "rb") as f:
    image_b64 = base64.b64encode(f.read()).decode()

llm = ChatGoogleGenerativeAI(model="gemini-2.5-flash")


message = HumanMessage(content=[
    {
        "type": "image_url", 
        "image_url": {"url": f"data:image/png;base64,{image_b64}"}
    },
    {
        "type": "text",      
        "text": "This is a blood work report. Extract all test results and flag any values outside the normal range."
    }
])

# Invoke the model
response = llm.invoke([message])
print(response.content)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 7
#       3
#       4 llm = ChatGoogleGenerativeAI(model="gemini-2.5-flash")
#       5
#       6
# ----> 7 message = HumanMessage(content=[
#       8     {
#       9         "type": "image_url",
#      10         "image_url": {"url": f"data:image/png;base64,{image_b64}"}
#
# NameError: name 'HumanMessage' is not defined
